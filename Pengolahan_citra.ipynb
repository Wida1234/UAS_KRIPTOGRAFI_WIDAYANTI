# %% [markdown]
# <a href="https://colab.research.google.com/github/Wida1234/UAS_KRIPTOGRAFI_WIDAYANTI/blob/main/Pengolahan_citra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drives')
# Out:
# Mounted at /content/drives

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
Gb1 = cv2.imread("/content/drives/MyDrive/Colab Notebooks/gambar.jpg")
Gb2 = cv2.imread("/content/drives/MyDrive/Colab Notebooks/main_hmti.jpg")

# %%
cv2_imshow(Gb1)
cv2_imshow(Gb2)
# Out:
# <PIL.Image.Image image mode=RGB size=6625x5000>
# <PIL.Image.Image image mode=RGB size=1280x720>
